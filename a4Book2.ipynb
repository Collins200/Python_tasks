# %%
# libraries
import os
from urllib.request import urlretrieve

# %%
def download_text(url):
    guten= os.path.basename(url)
    if not os.path.exists(guten):
        urlretrieve(url, guten)
        return guten

# %%
url='https://www.gutenberg.org/files/1342/1342-0.txt'
fname = download_text(url)

# %%
# print(fname)

# %%
def read_file(filename):
    file=open(filename,'r')
    return file.readlines()

# %%
read_file('1342-0.txt')
# Out:
# ['\ufeffThe Project Gutenberg eBook of Pride and Prejudice, by Jane Austen\n',
#  '\n',
#  'This eBook is for the use of anyone anywhere in the United States and\n',
#  'most other parts of the world at no cost and with almost no restrictions\n',
#  'whatsoever. You may copy it, give it away or re-use it under the terms\n',
#  'of the Project Gutenberg License included with this eBook or online at\n',
#  'www.gutenberg.org. If you are not located in the United States, you\n',
#  'will have to check the laws of the country where you are located before\n',
#  'using this eBook.\n',
#  '\n',
#  'Title: Pride and Prejudice\n',
#  '\n',
#  'Author: Jane Austen\n',
#  '\n',
#  'Release Date: June, 1998 [eBook #1342]\n',
#  '[Most recently updated: August 23, 2021]\n',
#  '\n',
#  'Language: English\n',
#  '\n',
#  'Character set encoding: UTF-8\n',
#  '\n',
#  'Produced by: Anonymous Volunteers and David Widger\n',
#  '\n',
# ...

# %%
my_list=read_file('1342-0.txt')

# %%
my_list.index('*** START OF THE PROJECT GUTENBERG EBOOK PRIDE AND PREJUDICE ***\n')
# Out:
# 23

# %%
my_list.index('*** END OF THE PROJECT GUTENBERG EBOOK PRIDE AND PREJUDICE ***\n')
# Out:
# 14231

# %%
values=my_list[24:14231]

# %%
# removing '/n' in the list
final_list=[]
for element in values:
    final_list.append(element.strip())

# %%
# final_list

# %%
# removing empty string in the list
result = []
for element in final_list:
    if element.strip():
        result.append(element)

# %%
for i in range(len(result)):
    result[i] = result[i].lower()

# %%
# result

# %%
def vowelCounterbefore(r):
    vowels = 'aeiouyàâæèéêëîïôùûüÿœ'
    v_count = 0
    c_count= 0

    for char in ''.join(r):
        if char in vowels:
            v_count += 1
        elif char != ' ':
            c_count += 1

    return ["Number of vowels before: ", v_count,"Number of consonants before: ", c_count]

# %%
vowelCounterbefore(result)
# Out:
# ['Number of vowels before: ', 216806, 'Number of consonants before: ', 344331]

# %%
def simplify(text):
    import unicodedata
    try:
        text = unicode(text, 'utf-8')
    except NameError:
        pass
    text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
    return str(text)

# %%
t=result

# %%
 # using list comprehension
listToStr = ','.join(map(str, t))

# %%
z=simplify(listToStr)

# %%
y=z.split(",")

# %%
def vowelCounterafter(r):
    vowels = 'aeiouy'
    v_count_after = 0
    c_count_after= 0

    for char in ''.join(r):
        if char in vowels:
            v_count_after += 1
        elif char != ' ':
            c_count_after += 1
   
    return ["Number of vowels after: ", v_count_after,"Number of consonants after: ", c_count_after]

# %%
vowelCounterafter(y)
# Out:
# ['Number of vowels after: ', 216806, 'Number of consonants after: ', 330514]

# %%
vowel_conversion_change=((216806-216806)/216806)*100

# %%
consonants_conversion_change=((330514-344331)/344331)*100

# %%
import pickle
with open('a4Book2', 'w') as f:
    f.write('From Project Gutenberg (www.gutenberg.org)'+"\n")
    f.write('Converted by: Iamma Huskie'+"\n")
    f.write('\n')
    f.write('*** START OF THE EBOOK ***'+"\n")
    f.write(str(y)+"\n")
    f.write('*** END OF THE EBOOK ***'+"\n")
    f.write(str(vowelCounterbefore(result)))
    f.write('\n')
    f.write(str(vowelCounterafter(y)))
    f.write('\n')
    f.write('Vowel Conversion Change: ')
    f.write(str(vowel_conversion_change)+"%")
    f.write('\n')
    f.write('Consonants Conversion Change: ')
    f.write(str(consonants_conversion_change)+"%")
